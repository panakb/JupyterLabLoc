# %% [markdown]
# <img height="180px" src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" align="left" hspace="30px" vspace="50px"/>
#
# # Welcome to your next notebook with SDA!
#
# During the classes we will mostly use [Google Colaboratory](https://colab.research.google.com/?hl=en) which is a free Jupyter notebook environment that requires no setup and runs entirely in the cloud.
#
# However, for bigger projects, especially involving Deep Learning and/or big data reading, it might be a better choice to setup Jupyter Notebook or Jupyter Lab on your computer. Also, it is worth noticing that there is a great number of useful extensions (see [nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/index.html) and [jupyter-labextension](https://jupyterlab.readthedocs.io/en/stable/user/extensions.html)) not available for Colab users.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1yaT5P7YcVbo--V_PWIfwi83K7F5LJlGX" alt="Where are we?" title="Where are we? Intermediate Python" align="left" width="1000px" hspace="10px" vspace="10px"/>

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1UO2urRciECzoKE_vHy4RMGfFbkOWOGlW" alt="SDA logo" align="left" width="100px" hspace="10px" vspace="10px"/>
#
# # Python in Data Science
# Start by reading through the presentation slides.
#
# <br>
#
# After the **<font color='#ed7d31'>PYTHON IN DATA SCIENCE</font>** course you will dive deeper into Python and familiarize yourself with concepts especially useful for future Data Scientists:
# * virtual environments
# * operations on files
# * pandas
# * working with dates and times
# * Practice❗

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
# <br>
#
# ## Virtual environments
#
# **<font color='#ed7d31'>PRACTICAL WORKSHOPS WITH SCREEN SHARING BY YOUR MENTOR</font>**
#
# ### Additional reading:
#
# By default, `pip` will install packages globally for the whole system. In most cases, this is not the desired action. We can have **many different projects** on a computer, each with its own set of dependencies. It may happen that the dependencies of one project are incompatible with the dependencies of another project. Does this mean we have to keep them on separate machines?
#
# `Virtualenv`, a **virtual environment**, comes to the rescue. You can create many virtual environments, each with its own set of dependencies kept in a place known only to that environment and not accessible to other environments.
# In this way, we get insulation and our designs do not interfere with each other.
# PyCharm has very good support for virtual environments. To install virtualenv you need to use
# ```bash
# pip install virtualenv
# ```
# and this is actually the only dependency you should install on your system globally.

# %% [markdown]
# The basic operation is, of course, to create a new virtual environment. The command virtualenv environment_name is used for this, where environment_name is the name of our choice.
#
# The question is where to keep the created virtual environments. In one approach, they can all be kept together in one dedicated directory.
#
# Another approach is to embed the virtual environment inside the project we are working on so that it becomes "self-sufficient". Usually, the environment is then called venv, a name recognized by Python programmers. The venv directory is then added to .gitignore so as not to track it in the repository. This approach is used by PyCharm, which we will discuss later.
#
# Either way, the virtualenv tool itself has no opinion on the localization of virtual environments. It will create a new environment in the current directory and it depends on us what this directory will be.

# %% [markdown]
# After creating a new environment, the next step is to **activate it**. This means that we would like to be in this new environment, so that we can install packages in it and develop a project that depends on them.
#
# In order to activate the environment, the script named activate, which is located in the virtual environment directory in the bin subdirectory, should be loaded into the current session.
#
# Loading the script into the session is done with the Linux source command.
# So if we are still in the same directory we were in when creating this environment, the correct command would be: source environment_name/bin/activate. (if we have several versions of Python on the computer, we can decide which one we want to use to create the environment by specifying the path in the -p parameter).
#
# While activating a virtual environment does not sound very simple, verifying whether we managed to activate it is hassle-free - if we are in the middle of a virtual environment, our command line will have its name added from now until we leave the environment.
#
# Also, pip freeze will return an empty list - there are no dependencies in the new virtual environment.
#
# Another way to check if the virtual environment is properly activated is to run the which python (or which python3) command in Linux, which should now return the path to Python from within the directory of our virtual environment.

# %% [markdown]
# Once we are in the middle of a virtual environment, we can install packages normally using the pip tool.
#
# A common situation is one where we created the environment because we want to start working on some project that exists on GitHub, let's say we want to get involved in some open source project.
#
# In such a situation, we will create a clean virtual environment, activate it and clone the project from GitHub. Usually, such a project will have a requirements.txt file, so we will execute the command
# ```bash
# pip install -r requirements.txt
# ```
# , which in our clean virtual environment will install all dependencies necessary to run the project.
#
# It may also happen that we are the main developers working on the project in a virtual environment, and another developer wants to join. Then we will check the dependencies in the project by running the
# ```bash
# pip freeze > requirements.txt
# ```
# command and we will share the resulting file with it so that it can easily recreate the environment.

# %% [markdown]
# Finally, there comes a point where we want to start working on a different project with a different set of dependencies.
#
# If we want to switch from one virtual environment to another, we first have to leave the one we are in. Use the `deactivate` command to do this.
#
# If we do it correctly, the environment name will disappear from our command line, pip freeze will show globally installed packages, and which python will point to python installed on the system or configured in the session.

# %% [markdown]
# **Extras - PyCharm**
#
# When creating a new project in PyCharm, it automatically creates a new virtual environment and embeds it inside the project in the venv directory.
# In the project creation dialog, we can select the environment creation tool (virtualenv, pipenv, conda), as well as select the Python version.
#
# If the project has been cloned from the repository, PyCharm will not create a virtual environment itself and you will have to configure it.
# To do this, select PyCharm -> Preferences -> Project -> Project Interpreter in OSX.
# For Linux it will be File -> Settings -> Project -> Project Interpreter.
# The dialog will then display the path to the Python interpreter - this will probably be your system Python. The currently installed packages will also be displayed along with their versions and whether there is a newer version of the package.
# We are most interested in the gear near the top right.
#
# After clicking on the gear, we choose the 'add' option and a new dialog appears in front of our eyes.
# We can use it to create a new virtual environment - by default named venv, located in the main project folder.
# We can also determine the version of Python installed on our system.
# Optionally, we can use the conda or pipenv tools or connect to Python on a remote machine via ssh or on a virtual machine using vagrant or on a container using a docker - all these options are quite advanced for our needs.
# We can also use the "system" global version of Python..
#
# The standard configured virtual environment in PyCharm is named venv and is visible in the project pane.
# The directory is underlined in red and is not added to the repository, the standard .gitignore file generated by GitHub for Python contains venv in it to ignore this folder.
# When a virtual environment is configured in PyCharm, it can index the code of dependent libraries and better validate the code.
# The terminal tab starts Bash immediately with the virtual environment activated.
# The Python Console tab runs Python from a configured virtual environment.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
#
# ## Conda Environments
#
# **<font color='#306998'>VIRTUAL ENVIRONMENTS </font><font color='#ffd33b'>WITH CONDA</font>**
#
# It might be also useful reading about conda environments: https://conda.io/projects/conda/en/latest/user-guide/index.html

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1UO2urRciECzoKE_vHy4RMGfFbkOWOGlW" alt="SDA logo" align="left" width="100px" hspace="10px" vspace="10px"/>
# <br>
#
# # Operations on files
#
# <br><br>

# %% [markdown]
# ## Read a file with `.open()` function
#
# To operate on files, you must first create a reference to the chosen one - use a built-in `.open()` function for this.
#
# `.open()` requires one parameter specified, ie. the path to the file you want to open. The path can be **<font color='#5b9bd5'>relative</font>** or **<font color='#5b9bd5'>absolute</font>**. By default, the file is opened in **read-only mode** and **text format**. If you want to operate on a binary file or write to it, the **write mode** should be specified as the second parameter.
#
# #### **<font color='#306998'>MOUNT </font><font color='#ffd33b'>GOOGLE DRIVE</font>**
#
# Download `sentences.txt` file from the following kaggle site:<br>
# https://www.kaggle.com/datasets/olgabelitskaya/toy-data-for-text-processing
#
# Upload it to your Google Drive, mount it and load the data.
#
# *Hint: you can copy the path to the file or change the working directory and then use just the file name with .txt extenstion.*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# e:\@DataScienceCZ7\JupyterLabLoc\6_Python_in_Data_Science.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/%40DataScienceCZ7/JupyterLabLoc/6_Python_in_Data_Science.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> from google.colab import drive
#       <a href='vscode-notebook-cell:/e%3A/%40DataScienceCZ7/JupyterLabLoc/6_Python_in_Data_Science.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
f = open('/content/drive/MyDrive/SDA Data Science/files/sentences.txt')

# %%
f
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/SDA Data Science/files/sentences.txt' mode='r' encoding='UTF-8'>

# %%
f.write('Another sentence')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-4-455ec225301f> in <cell line: 1>()
# ----> 1 f.write('Another sentence')
#
# UnsupportedOperation: not writable

# %%
f.close()

# %% [markdown]
# ### File open modes
#
# The `.open()` function has the following modes:
# * `"r"` - read only (default)
# * `"w"` - for writing, if the file does not exist it will be created, if it does exist the old contents will be deleted (over-written)
# * `"x"` - for creating, the operation will fail if the file already exists
# * `"a"` - appending, if the file does not exist, it will be created, if it exists, new content will be appended to the end of the file (you will not loose previous content)
# * `"t"` - text mode (default)
# * `"b"` - binary mode
# * `"+"` - means that when opened, the cursor will move to the end of the file. By default it is set at the beginning.
#
# The modes can be used together, e.g. `a + b` means opening a binary file for writing, but the file, if it exists, will not be shortened, and appending will be done at the end of the file.
#
# The last parameter of the `.open()` function is `encoding`, ie. file encoding (see more [text encoding](https://www.puredevsoftware.com/blog/2017/11/17/text-encoding/)). The default depends on the operating system, `cp1252` on Windows and `utf-8` on Linux.

# %% [markdown]
# ### Opening the file
#
# After you finish working on the file, each time, it needs to be closed. This is done with the `.close()` method called on an object of the File type.
#
# It's worth noting that the code below is not secure:

# %%
f = open('/content/drive/MyDrive/SDA Data Science/files/sentences.txt')

# do some stuff

f.close()

# %% [markdown]
# The best way to open a file is to use the file in a context using `with` keyword. The `with` keyword opens the context found in the indented block below it. When we leave the indented context block, the file will be automatically closed, so we don't have to close it ourselves.
#
# This eliminates the confusion caused by forgetting to close the file when not using the context manager and it also protects us in a situation when errors occur in the code and the file is not closed.

# %%
with open('/content/drive/MyDrive/SDA Data Science/files/sentences.txt') as f:
    pass
    # do some stuff

# file is automatically closed by now :)

# %% [markdown]
# ### Reading from file
#
# While working with **<font color='#5b9bd5'>text files</font>**, we very often want to **<font color='#5b9bd5'>read the file line by line</font>**.
#
# There are three main ways to read a file line by line;
# * the prehistoric approach
#     * using the `.readline()` method
#     ```python
#     file_path = '/content/drive/MyDrive/SDA Data Science/files/sentences.txt'
#
#     f = open(file_path)
#
#     while(True):
#         line = f.readline()
#         if not line:
#             break
#             f.close()
#         print(line)
#     ```
# * the medieval approach - using the `.readlines()` method
#     * `.readlines()` returns a list which elements are consecutive single lines read from the file
#     ```python
#     file_path = '/content/drive/MyDrive/SDA Data Science/files/sentences.txt'
#
#     with open(file_path) as f:
#         lines = f.readlines()
#         for line in lines:
#             print(line)
#     ```
#     > It can still be useful when we don't want to read line by line, but to navigate through the file the way we chose. Note, however, that readlines will read the entire file, regardless of its size.
# * the standard approach - use a lazy iterator returned by an object of `File` type.
#     * the file descriptor itself returns an iterator that passes line by line
#     > typically this is better than `.readlines()` because it does not read the entire file into the memory. This method is preferred.

# %%
file_path = '/content/drive/MyDrive/SDA Data Science/files/sentences.txt'

with open(file_path) as f:
    for line in f:
        print(line)
        break
# Out:
# I check my email every day.

# %% [markdown]
# ## Saving to file
#
# In order to **<font color='#5b9bd5'>write some content to a file</font>**, it must first be opened in appropriate mode (for writing and/or adding).
#
# If the file opening operation is successful (we have the appropriate permissions, there is enough space on the disk) then we can write the content to it using the `.write()` method.
#
# The `.write()` method takes as a parameter the string that we want to write to the file.
#
# In the example above, we have opened a text file (see `file.txt`) in the given directory (an absolute path was used). The file was opened in **<font color='#5b9bd5'>read-only mode</font>**, so if there was no such file (ie. the file did not exist) then it was created, and otherwise, its previous content was deleted.

# %%
with open('/content/drive/MyDrive/SDA Data Science/files/sentences_0.txt', 'w') as f:
    f.write('This is my first text file\n')
    f.write('Created in Python\n')

# %%
# !ls "/content/drive/MyDrive/SDA Data Science/files/"
# Out:
# chipotle.tsv  sentences_0.txt  sentences.txt

# %%
with open('/content/drive/MyDrive/SDA Data Science/files/sentences_0.txt') as f:
    for line in f:
        print(line)
# Out:
# This is my first text file
#
# Created in Python

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1UO2urRciECzoKE_vHy4RMGfFbkOWOGlW" alt="SDA logo" align="left" width="100px" hspace="10px" vspace="10px"/>
# <br>
#
# # pandas - Python Data Analysis Library
#
# <img src="https://drive.google.com/uc?export=view&id=1-IymXq4uU75EOw2ZEDoKt28FS4AGcVDF" alt="Pandas logo" title="Pandas logo" align="right" width="250px" hspace="60px" vspace="0px"/>
#
# <br><br>
# Pandas is another library essential for data analysis using Python. It provides powerful data structures that make working with **<font color='#5b9bd5'>tabular data</font>** simple and intuitive.
#
# Pandas developers aim to maintain its status as an essential library for everyday analysis. They also want to become the most powerful open-source tool for data analysis in any programming language. Currently, the project continues to grow rapidly, and familiarity with it is crucial for any data scientist.

# %% [markdown]
# **Pandas will be a good choice for the following uses:**
# * tabular data (with columns & rows as in SQL, Excel, or .csv files)
# * data representing time series
# * matrices
# * results of measurements and statistics
#
# <img src="https://drive.google.com/uc?export=view&id=1s2kYiPt5tJQcMb8CHwk91acjIpso4equ" alt="Pandas: tabular data" title="Pandas: tabular data" align="center" width="500px" hspace="30px" vspace="10px"/>
#
# > Source: https://www.geeksforgeeks.org/python-pandas-dataframe/
#
# **<font color='#5b9bd5'>Did you know?</font>** - `.csv` files are plain text files with comma-separated values, e.g. "James", "Bond", 007

# %% [markdown]
# **Pandas strengths include:**
# * simple handling of missing values (NaN),
# * ability to modify the size of the `pd.DataFrame()` - we can easily add and remove both columns and rows,
# * automatic data alignment in calculations (as in NumPy),
# * powerful `.groupby()` method allowing for data aggregation in the same way as in SQL,
#
# Additionaly, it's easy to create a `pd.DataFrame()` from other objects, and cutting, indexing or creating subsets, as well as joining (join and merge) different data sets together.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
#
# ## Pandas data structures - `pd.Series()`
#
# **<font color='#5b9bd5'>Pandas Series</font>** is a one-dimensional data structure (similar to one-dimensional NumPy matrix, ie. vector) that stores the data as well as unique indeces.
#
# Creating with `pd.Series(<content>)`:

# %%
import pandas as pd

pd.Series(range(123, 115, -1))
# Out:
# 0    123
# 1    122
# 2    121
# 3    120
# 4    119
# 5    118
# 6    117
# 7    116
# dtype: int64

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
#
# ## Pandas data structures - `pd.DataFrame()`
#
# The second structure introduced in pandas is **<font color='#5b9bd5'>Pandas DataFrame</font>**. It is a two or more dimensional data structure, most often in the form of a table with rows and columns. Typically, columns have their names and rows have indexes.
#
# Creating - `pd.DataFrame(<content>)`

# %%
pd.DataFrame([[5, 2], [7, 13]])
# Out:
#    0   1
# 0  5   2
# 1  7  13

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
#
# ## Reading data with Pandas
#
# Even though it is possible to define the data on your own and create a `pd.Series()` or `pd.DataFrame()`, typically, we do not do that. The first step is usually the same - there is some data is stored in `.csv`, or `.tsv` files, databases, excel files etc. You can load them by using previously described methods or directly using pandas API with `pd.read_csv()` function:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#
# Note that the list of all possible arguments is very large and at first it might be a bit overwhelming. However, we strongly encorage you to familiarize with the most important ones, since they will make your life a lot easier!
#
# ```python
# pandas.read_csv(filepath_or_buffer, *, sep=_NoDefault.no_default, delimiter=None, header='infer', names=_NoDefault.no_default, index_col=None, usecols=None, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=None, infer_datetime_format=_NoDefault.no_default, keep_date_col=False, date_parser=_NoDefault.no_default, date_format=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal='.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, encoding_errors='strict', dialect=None, on_bad_lines='error', delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None, storage_options=None, dtype_backend=_NoDefault.no_default)
# ```
#
# * `filepath_or_buffer`
# * `sep` / `delimiter` - column separator (comma by default)
# * `header` - row with columns names (if available)
# * `index_col` - to specify which column contains data indices
# * `usecols` - if you need to load only selected columns
# * `skiprows` - if initial rows contain some meta-data that you do not need
# * `nrows` - to load only a limited portion of a data
# * `chunksize` - if you want to instantiate data reader (generator) to load data in chunks
# * `names` - if they are not available or you want to change the default ones
# * and many others!

# %% [markdown]
# #### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Download `chipotle.tsv` file from the following kaggle site:
# https://www.kaggle.com/datasets/navneethc/chipotle
#
# Upload it to your Google Drive, mount it and load the data.
#
# *Hint: you can copy the path to the file or change the working directory and then use just the file name with .tsv extenstion.*

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
chipotle = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/6 Python in Data Science/chipotle.tsv", sep="\t")
    # "/content/drive/MyDrive/SDA Data Science/files/chipotle.tsv"
chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
#
# ## Display data
#
# After the data is loaded, the next step is to display it and you can do it in many ways:
# * simply print out what will fit on the screen with `df` (here `chipotle`)
# * `df.head(n)` - displays the first n data records (5 by default)
# * `df.tail(n)` - displays the last n data records (5 by default)
# * `df.sample(n)` - displays n randomly chosen data records (1 by default)
# * `df[“column”]` or `df.column` - displays a given column (as `pd.Series()`)
#     * note that so-called the dot-notation is possible only for column names without whitespace characters❗
# * `df[[“column”]]` - displays a given column (as `pd.DataFrame()`)
# * `df[[“column1”, “column2”]]` - displays several columns
#     * note that you cannot specify multiple columns with single-square brackets notation❗
# * `df.index` - displays indexes
# * `df.columns` - displays column names
# * `df.info()` - general information about the data set (incl. missing values and data types)

# %%
chipotle.sample()
# Out:
#       order_id  quantity         item_name  \
# 4141      1657         1  Carnitas Burrito
#
#                                      choice_description item_price
# 4141  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...    $11.75

# %%
chipotle.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipotle.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipotle.item_price
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
chipotle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# ### Subset data rows/cols with `.loc[]/.iloc[]`
#
# For the `pd.DataFrame()`, there are two pandas methods for retrieving specific data:
# * `.loc[[rows],[cols]]` - looks for columns and indexes by their names
# * `.iloc[[row_numbers], [col_numbers]]` - searches by their ordinal numbers

# %%
chipotle['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
chipotle[0:3]  # rows from 0 to 3, wo 3 (left-hand closed right-hand open)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %%
chipotle.loc[:, 'item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
chipotle.loc[:5, 'item_price']

chipotle.loc[2:5, 'item_price']
# Out:
# 2     $3.39
# 3     $2.39
# 4    $16.98
# 5    $10.98
# Name: item_price, dtype: object

# %%
chipotle.loc[:, ['quantity', 'item_price']]
# Out:
#       quantity item_price
# 0            1     $2.39
# 1            1     $3.39
# 2            1     $3.39
# 3            1     $2.39
# 4            2    $16.98
# ...        ...        ...
# 4617         1    $11.75
# 4618         1    $11.75
# 4619         1    $11.25
# 4620         1     $8.75
# 4621         1     $8.75
#
# [4622 rows x 2 columns]

# %%
chipotle.loc[13, ['quantity', 'item_price']]  # only one row
# Out:
# quantity            1
# item_price    $11.25
# Name: 13, dtype: object

# %%
chipotle.loc[13, ['item_price']]  # selected single cell (with indices)
# Out:
# item_price    $11.25
# Name: 13, dtype: object

# %%
chipotle.loc[13, 'item_price']  # selected single cell
# Out:
# '$11.25 '

# %%
chipotle.at[13, 'item_price']  # selected single cell
# Out:
# '$11.25 '

# %% [markdown]
# Note that `.iloc[0]` and `.loc[0]` will not differ if the following indexes are consecutive numbers starting from 0.

# %%
chipotle.iloc[0]
# Out:
# order_id                                         1
# quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 0, dtype: object

# %%
chipotle.loc[0]
# Out:
# order_id                                         1
# quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 0, dtype: object

# %% [markdown]
# However, if we start indexing from 1 (or shuffle data, or drop a few rows) these two will be significantly different.

# %%
chipotle.index += 1

# %%
chipotle.iloc[1]
# Out:
# order_id                         1
# quantity                         1
# item_name                     Izze
# choice_description    [Clementine]
# item_price                  $3.39
# Name: 2, dtype: object

# %%
chipotle.loc[1]
# Out:
# order_id                                         1
# quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 1, dtype: object

# %% [markdown]
# ### Data filtering with logical conditions
#
# Note that you can easily introduce various logical expressions to evaluate each cell value one-by-one:

# %%
chipotle["quantity"] > 5
# Out:
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# 4622    False
# Name: quantity, Length: 4622, dtype: bool

# %% [markdown]
# What is more, you can use it in square brackets to select only the rows satisfying the given conditions:

# %%
chipotle[chipotle["quantity"] > 5]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3599      1443        15  Chips and Fresh Tomato Salsa                NaN
# 3600      1443         7                 Bottled Water                NaN
# 3888      1559         8                 Side of Chips                NaN
# 4153      1660        10                 Bottled Water                NaN
#
#      item_price
# 3599    $44.25
# 3600    $10.50
# 3888    $13.52
# 4153    $15.00

# %%
chipotle[chipotle["order_id"] <= 2]
# Out:
#    order_id  quantity                              item_name  \
# 1         1         1           Chips and Fresh Tomato Salsa
# 2         1         1                                   Izze
# 3         1         1                       Nantucket Nectar
# 4         1         1  Chips and Tomatillo-Green Chili Salsa
# 5         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 1                                                NaN     $2.39
# 2                                       [Clementine]     $3.39
# 3                                            [Apple]     $3.39
# 4                                                NaN     $2.39
# 5  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipotle[(chipotle["order_id"] > 1405) & (chipotle["order_id"] <= 1410)]
# Out:
#       order_id  quantity                     item_name  \
# 3502      1406         1                 Steak Burrito
# 3503      1406         1                   Steak Salad
# 3504      1407         1            Steak Crispy Tacos
# 3505      1407         1  Chips and Fresh Tomato Salsa
# 3506      1408         1                  Chicken Bowl
# 3507      1408         1  Chips and Fresh Tomato Salsa
# 3508      1409         2            Chicken Salad Bowl
# 3509      1410         2                  Chicken Bowl
#
#                                      choice_description item_price
# 3502                  [[Lettuce, Fajita Veggies, Rice]]     $8.69
# 3503                        [[Lettuce, Fajita Veggies]]     $8.69
# 3504                               [Fresh Tomato Salsa]     $9.25
# 3505                                                NaN     $2.95
# 3506  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $10.98
# 3507                                                NaN     $2.39
# ...

# %%
chipotle[(chipotle["order_id"] > 1830) | (chipotle["quantity"] > 4)]
# Out:
#       order_id  quantity                     item_name  \
# 2442       970         5                 Bottled Water
# 3599      1443        15  Chips and Fresh Tomato Salsa
# 3600      1443         7                 Bottled Water
# 3888      1559         8                 Side of Chips
# 4153      1660        10                 Bottled Water
# 4613      1831         1                 Carnitas Bowl
# 4614      1831         1                         Chips
# 4615      1831         1                 Bottled Water
# 4616      1832         1            Chicken Soft Tacos
# 4617      1832         1           Chips and Guacamole
# 4618      1833         1                 Steak Burrito
# 4619      1833         1                 Steak Burrito
# 4620      1834         1            Chicken Salad Bowl
# 4621      1834         1            Chicken Salad Bowl
# 4622      1834         1            Chicken Salad Bowl
#
#                                      choice_description item_price
# ...

# %%
chipotle[chipotle["item_name"] == "Bottled Water"]
# Out:
#       order_id  quantity      item_name choice_description item_price
# 35          17         1  Bottled Water                NaN     $1.09
# 88          38         1  Bottled Water                NaN     $1.09
# 319        138         1  Bottled Water                NaN     $1.09
# 330        143         1  Bottled Water                NaN     $1.50
# 377        163         1  Bottled Water                NaN     $1.50
# ...        ...       ...            ...                ...        ...
# 4569      1817         1  Bottled Water                NaN     $1.50
# 4571      1817         1  Bottled Water                NaN     $1.50
# 4583      1822         2  Bottled Water                NaN     $3.00
# 4599      1826         1  Bottled Water                NaN     $1.50
# 4615      1831         1  Bottled Water                NaN     $1.50
#
# [162 rows x 5 columns]

# %% [markdown]
# ### Overwriting data
#
# You can also overwrite or append data with the assignment command `=`:
# ```python
# df[“column”] = new_data_series
# df[[“column”]] = new_dataframe
# df[[“column1”, “column2”]] = new_dataframe
# df.loc[column:row] = new_dataframe
# df.iloc[column_number:row_number] = new_dataframe
# ```

# %%
chipotle['new_col'] = 'oh'

# %%
chipotle.head()
# Out:
#    order_id  quantity                              item_name  \
# 1         1         1           Chips and Fresh Tomato Salsa
# 2         1         1                                   Izze
# 3         1         1                       Nantucket Nectar
# 4         1         1  Chips and Tomatillo-Green Chili Salsa
# 5         2         2                           Chicken Bowl
#
#                                   choice_description item_price new_col
# 1                                                NaN     $2.39       oh
# 2                                       [Clementine]     $3.39       oh
# 3                                            [Apple]     $3.39       oh
# 4                                                NaN     $2.39       oh
# 5  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       oh

# %%
chipotle = chipotle.drop(columns=['new_col'])

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
#
# ## Basic statistics
#
# All the following operations for the DataFrame will return values for each of the columns. We can also select the column for which we want to perform these operations:
# ```python
# df.count()  # counting the number of items (not NaNs)
# df.column.value_counts()  # counting the number of unique items
# df.sum()  # sum of all items
# df.min()  # minimal element
# df.max()  # maximal element
# df.mean()  # dataset’s mean
# df.median()  # dataset’s median
# ```

# %%
chipotle['quantity'].value_counts()
# Out:
# 1     4355
# 2      224
# 3       28
# 4       10
# 5        1
# 15       1
# 7        1
# 8        1
# 10       1
# Name: quantity, dtype: int64

# %%
chipotle['quantity'].sum()
# Out:
# 4972

# %%
chipotle['quantity'].min(), chipotle['quantity'].max()
# Out:
# (1, 15)

# %%
chipotle['quantity'].mean()
# Out:
# 1.0757247944612722

# %% [markdown]
# **<font color='#5b9bd5'>Please see [TASK 1](#scrollTo=z5eXe9__yhZ6) & [TASK 2](#scrollTo=o5y-XYr4bcv1).</font>**

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
#
# ## Operating on data

# %% [markdown]
# ### .apply()
#
# All the following operations for the dataframe will return values for each of the columns, we can select the column for which we want to perform these actions:
# > `df.apply(function)` - applying a function to each column or cell in the set

# %%
chipotle['item_price [$]'] = chipotle['item_price'].apply(lambda x: float(x[1:]))

# %%
chipotle['item_price [$]'].apply(round)
# chipotle['item_price [$]'].apply(lambda x: round(x))
# Out:
# 0        2
# 1        3
# 2        3
# 3        2
# 4       17
#         ..
# 4617    12
# 4618    12
# 4619    11
# 4620     9
# 4621     9
# Name: item_price [$], Length: 4622, dtype: int64

# %% [markdown]
# **<font color='#5b9bd5'>Please see [TASK 3](#scrollTo=WKJVnZD9iAyI).</font>**

# %% [markdown]
# ### .groupby()
#
# You need to segment your database from time to time. In addition to computing statistics for all values, sometimes these values can be grouped. In pandas, the `.groupby()` method is used for this purpose.
# ```python
# df.groupby(“column”).operation().column
# ```

# %%
chipotle.groupby('item_name')

# %%
chipotle['sales'] = (chipotle["item_price [$]"] * chipotle.quantity)

chipotle.groupby(['item_name','choice_description']).agg(
    item_price_min=('item_price [$]', 'min'),
    item_price_max=('item_price [$]', 'max'),
    quantity_mean=('quantity', 'mean'),
    sales_sum=('sales','sum'),
    )
# Out:
#                                                                       item_price_min  \
# item_name         choice_description
# 6 Pack Soft Drink [Coke]                                                        6.49
#                   [Diet Coke]                                                   6.49
#                   [Lemonade]                                                    6.49
#                   [Nestea]                                                      6.49
#                   [Sprite]                                                      6.49
# ...                                                                              ...
# Veggie Soft Tacos [Fresh Tomato Salsa, [Black Beans, Cheese, Sour...            8.75
#                   [Fresh Tomato Salsa, [Fajita Vegetables, Rice, ...           11.25
#                   [Roasted Chili Corn Salsa (Medium), [Black Bean...            8.49
#                   [Roasted Chili Corn Salsa, [Fajita Vegetables, ...            8.75
# ...

# %%
chipotle[['item_name', 'item_price [$]', 'quantity']].groupby('item_name').max().head()
# Out:
#                        item_price [$]  quantity
# item_name
# 6 Pack Soft Drink               12.98         2
# Barbacoa Bowl                   11.75         1
# Barbacoa Burrito                11.75         1
# Barbacoa Crispy Tacos           18.50         2
# Barbacoa Salad Bowl             11.89         1

# %%
chipotle[chipotle['item_name'] == "6 Pack Soft Drink"]
# Out:
#       order_id  quantity          item_name choice_description item_price  \
# 299        129         1  6 Pack Soft Drink           [Sprite]     $6.49
# 342        148         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 358        154         1  6 Pack Soft Drink             [Coke]     $6.49
# 389        168         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 418        182         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 554        230         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 640        264         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 722        298         1  6 Pack Soft Drink           [Nestea]     $6.49
# 744        306         1  6 Pack Soft Drink             [Coke]     $6.49
# 880        363         1  6 Pack Soft Drink             [Coke]     $6.49
# 1027       422         1  6 Pack Soft Drink           [Sprite]     $6.49
# 1052       432         1  6 Pack Soft Drink             [Coke]     $6.49
# ...

# %% [markdown]
# ### Removing data
#
# The df.drop() command is used to delete data - as a parameter we give a list of indexes or columns to be deleted and axis - whether an index or a column should be deleted.

# %%
chipotle.drop(columns='item_price')
# chipotle.drop('item_price', axis=1)
# Out:
#       order_id  quantity                              item_name  \
# 1            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                                   Izze
# 3            1         1                       Nantucket Nectar
# 4            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4618      1833         1                          Steak Burrito
# 4619      1833         1                          Steak Burrito
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
# 4622      1834         1                     Chicken Salad Bowl
#
#                                      choice_description
# 1                                                   NaN
# 2                                          [Clementine]
# ...

# %%
# chipotle = chipotle.drop(columns='item_price')
# or
chipotle.drop(columns='item_price', inplace=True)

# %% [markdown]
# We can also remove incomplete data (NaNy) with the df.dropna() command - the axis parameter removes columns or rows.

# %%
chipotle.dropna()
# Out:
#       order_id  quantity           item_name  \
# 2            1         1                Izze
# 3            1         1    Nantucket Nectar
# 5            2         2        Chicken Bowl
# 6            3         1        Chicken Bowl
# 8            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4618      1833         1       Steak Burrito
# 4619      1833         1       Steak Burrito
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
# 4622      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price [$]
# 2                                          [Clementine]            3.39
# 3                                               [Apple]            3.39
# 5     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...           16.98
# 6     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...           10.98
# ...

# %%
len(chipotle), len(chipotle.dropna())
# Out:
# (4622, 3376)

# %% [markdown]
# ### Merging data
#
# In fact, often instead of using one large database, we connect many smaller ones (it is easier to manage them, avoid redundancy, additionally we save disk space and achieve higher speed). Moreover, often the data comes from various sources, hence is splitted naturally betwenn files.
#
# We can combine the data in the library in a few ways:
# * `df.append(object)` method adds new rows to the end of the existing dataframe
# * `df.merge()` method, which in its assumptions is very similar to `SQL JOIN` - you can choose the joining method - inner (common), outer (sum), left, right and specify the `on` parameter - the name of the column to be a hyphen.
#
# Additionally, we can give the new column name ourselves and thus add the data to the existing data: df ["new column"] = data
#
# There are also other methods, such as, `pd.concat()` and `pd.join()`, see more https://pandas.pydata.org/docs/user_guide/merging.html.

# %% [markdown]
# ### Sorting data
#
# You can also use a method `df.sort_values(by="column name")`
# with `ascending` parameter set to `True` for ascending order and `False` for descending one.
#
# Moreover, often, after sorting the dataset, we want to drop the old indexes - the `df.reset_index(drop=True)` is used for this.

# %%
chipotle.sort_values('quantity')
# Out:
#       order_id  quantity                     item_name  \
# 1            1         1  Chips and Fresh Tomato Salsa
# 3021      1201         1                   Canned Soda
# 3022      1201         1                 Bottled Water
# 3023      1201         1                 Side of Chips
# 3024      1202         1                  Chicken Bowl
# ...        ...       ...                           ...
# 2442       970         5                 Bottled Water
# 3600      1443         7                 Bottled Water
# 3888      1559         8                 Side of Chips
# 4153      1660        10                 Bottled Water
# 3599      1443        15  Chips and Fresh Tomato Salsa
#
#                                      choice_description  item_price [$]
# 1                                                   NaN            2.39
# 3021                                  [Diet Dr. Pepper]            1.09
# 3022                                                NaN            1.09
# ...

# %%
chipotle.sort_values('item_price [$]', ascending=False)
# Out:
#       order_id  quantity                     item_name  \
# 3599      1443        15  Chips and Fresh Tomato Salsa
# 3481      1398         3                 Carnitas Bowl
# 1255       511         4               Chicken Burrito
# 3603      1443         4               Chicken Burrito
# 3602      1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 3937      1578         1                   Canned Soda
# 2923      1162         1                 Bottled Water
# 1397       567         1                   Canned Soda
# 2563      1014         1                   Canned Soda
# 1458       591         1                   Canned Soda
#
#                                      choice_description  item_price [$]
# 3599                                                NaN           44.25
# 3481  [Roasted Chili Corn Salsa, [Fajita Vegetables,...           35.25
# 1255  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...           35.00
# ...

# %%
chipotle.sort_values('item_price [$]', ascending=False).reset_index()  # inplace & drop
# Out:
#       index  order_id  quantity                     item_name  \
# 0      3599      1443        15  Chips and Fresh Tomato Salsa
# 1      3481      1398         3                 Carnitas Bowl
# 2      1255       511         4               Chicken Burrito
# 3      3603      1443         4               Chicken Burrito
# 4      3602      1443         3                Veggie Burrito
# ...     ...       ...       ...                           ...
# 4617   3937      1578         1                   Canned Soda
# 4618   2923      1162         1                 Bottled Water
# 4619   1397       567         1                   Canned Soda
# 4620   2563      1014         1                   Canned Soda
# 4621   1458       591         1                   Canned Soda
#
#                                      choice_description  item_price [$]
# 0                                                   NaN           44.25
# 1     [Roasted Chili Corn Salsa, [Fajita Vegetables,...           35.25
# ...

# %% [markdown]
# ### Dealing with missing data
#
# Missing data is a fairly common problem faced by Data Analysts and Data Scientist. There are two main approaches:
# * `df.dropna()` method - removes all rows with empty data from the table
# * `df.fillna(value)` method- fills (or imputes) the data with the specified value
#
# Later on you will also know some more advanced methods to impute missing data. What are your thoughts? What number should be given to the `<value>` to fill in missing observations?

# %%
chipotle.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# item_price [$]           0
# sales                    0
# dtype: int64

# %%
chipotle['choice_description'].fillna("No description")
# Out:
# 1                                          No description
# 2                                            [Clementine]
# 3                                                 [Apple]
# 4                                          No description
# 5       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4618    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4619    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4622    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %% [markdown]
# **<font color='#5b9bd5'>See [TASK 4](#scrollTo=6pYv40ppiiEQ), [TASK 5](#scrollTo=CjRm3IXFf1wm) & [TASK 6](#scrollTo=L0xzGLGFgKpK).</font>**

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
#
# ## Data analysis
#
# Data understanding - collecting specific data needed to perform the following tasks:
# * solve the problem
# * provide data description (sometimes also labeling),
# * exploration and quality verification.
#
# <br><br><br>
# <img src="https://drive.google.com/uc?export=view&id=1T8Uz4wJwFkqid0Erpboe3HvD_yhsRyrM" alt="Data analysis process" title="Data analysis process" align="right" width="600px" hspace="60px" vspace="00px"/>
#
# Data types - `.csv` sheets (these are the ones we will be working on today), text, image, sound, video, weather data, stock data, public archives, etc.
#
# The most important task - FEATURE EXTRACTION (feature engineering). A lot depends on the size of the set and the number of features - depending on these parameters, we will take different steps in the data analysis process.

# %% [markdown]
# ### Types of features
#
# <img src="https://drive.google.com/uc?export=view&id=1hs-uBkz5exZMEdij-vpnmY-CRC5Nl2il" alt="Data analysis process" title="Data analysis process" align="left" width="600px" hspace="20px" vspace="20px"/>

# %% [markdown]
# ### Data aggregation
#
# * Numeric:
#     * mean
#     * sum,
#     * max
#     * min
#     * standard deviation
# * Categorical:
#     * counting the appearances
#     * searching for the most common
#     * percentage results, e.g. 23% of the population are blondes

# %% [markdown]
# Incomplete values - how to deal with them:
# * ignore them
# * insert the value "unknown"
# * manually fill in on the basis of accumulated knowledge
# * delete records with incomplete data
# * complete algorithmically
#     * look for the nearest neighbor
#     * take the average
#     * insert random values
#     * create ML algorithm

# %%
threshold = 0.2

chipotle.columns[chipotle.isnull().mean() < threshold]
# Out:
# Index(['order_id', 'quantity', 'item_name', 'item_price', 'item_price [$]',
#        'sales'],
#       dtype='object')

# %%
# drop columns with more than 20% of missing data
chipotle[chipotle.columns[chipotle.isnull().mean() <= threshold]]
# Out:
#       order_id  quantity                              item_name item_price  \
# 0            1         1           Chips and Fresh Tomato Salsa     $2.39
# 1            1         1                                   Izze     $3.39
# 2            1         1                       Nantucket Nectar     $3.39
# 3            1         1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2         2                           Chicken Bowl    $16.98
# ...        ...       ...                                    ...        ...
# 4617      1833         1                          Steak Burrito    $11.75
# 4618      1833         1                          Steak Burrito    $11.75
# 4619      1834         1                     Chicken Salad Bowl    $11.25
# 4620      1834         1                     Chicken Salad Bowl     $8.75
# 4621      1834         1                     Chicken Salad Bowl     $8.75
#
#       item_price [$]  sales
# 0               2.39   2.39
# ...

# %%
# drop rows with at least 20% of missing data (here one value)
chipotle.loc[chipotle.isnull().mean(axis=1) < threshold]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                   NaN     $2.39
# ...

# %%
import numpy as np


chipotle['item_price [$]'] = chipotle['item_price [$]'].replace(8.75, np.NaN)

# %%
chipotle.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# item_price [$]         730
# sales                    0
# dtype: int64

# %%
chipotle.fillna(0)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                     0     $2.39
# ...

# %%
chipotle.fillna(chipotle['item_price [$]'].median())
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                  8.49     $2.39
# ...

# %%
# missing categorical features replaced the most frequent category
chipotle.fillna(chipotle['choice_description'].value_counts().idxmax())
# Out:
#       order_id  quantity                              item_name  \
# 1            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                                   Izze
# 3            1         1                       Nantucket Nectar
# 4            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4618      1833         1                          Steak Burrito
# 4619      1833         1                          Steak Burrito
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
# 4622      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price [$]
# 1                                           [Diet Coke]           2.39
# ...

# %% [markdown]
# ## Data preprocessing / cleaning (noise removal)
#
# <img src="https://drive.google.com/uc?export=view&id=19yZ4fZuosFbjGLp_yCRS0mSKBSFv0v0Z" alt="Data processing: outliers" title="Data processing: outliers" align="left" width="600px" hspace="20px" vspace="20px"/>

# %% [markdown]
# Remove outliers with standard deviation.

# %% [markdown]
# pravidlo 3 sigma - (odchylka = sigma)
# tedy trojnásobek směrodatné odchylky

# %%
# dropping outlier observations (ie. rows) based on standard deviation
factor = 3

item_price_mean = chipotle['item_price [$]'].mean()
item_price_std = chipotle['item_price [$]'].std()

print(f"mean: {item_price_mean} and std: {item_price_std}")

upper_lim = item_price_mean + item_price_std * factor
lower_lim = item_price_mean - item_price_std * factor

print(f"upper_lim: {upper_lim} and lower_lim: {lower_lim}")

mask = (chipotle['item_price [$]'] < upper_lim) & (chipotle['item_price [$]'] > lower_lim)
chipotle[mask].sort_values('item_price [$]',ascending=False)
# Out:
# mean: 7.223191161356629 and std: 4.586736091571879
# upper_lim: 20.98339943607227 and lower_lim: -6.537017113359008
#       order_id  quantity              item_name  \
# 2581      1024         2       Carnitas Burrito
# 534        223         2          Steak Burrito
# 4310      1719         2          Steak Burrito
# 3354      1345         2             Steak Bowl
# 1903       768         2  Barbacoa Crispy Tacos
# ...        ...       ...                    ...
# 1948       788         1            Canned Soda
# 3581      1436         1          Bottled Water
# 473        202         1            Canned Soda
# 1457       591         1            Canned Soda
# 2584      1025         1            Canned Soda
#
#                                      choice_description item_price  \
# 2581  [Tomatillo Red Chili Salsa, [Rice, Pinto Beans...    $18.50
# 534   [Fresh Tomato Salsa, [Sour Cream, Lettuce, Che...    $18.50
# 4310  [Tomatillo Red Chili Salsa, [Rice, Black Beans...    $18.50
# ...

# %%
# pay attention to missing data!
chipotle[~mask]
# Out:
#       order_id  quantity             item_name  \
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 19          10         1          Chicken Bowl
# 35          18         1    Chicken Soft Tacos
# 36          18         1    Chicken Soft Tacos
# ...        ...       ...                   ...
# 4599      1827         1          Chicken Bowl
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 35                     [Roasted Chili Corn Salsa, Rice]     $8.75
# ...

# %% [markdown]
# Removing outliers with percentiles:

# %%
upper_lim = chipotle['item_price [$]'].quantile(.95)
lower_lim = chipotle['item_price [$]'].quantile(.05)

chipotle[(chipotle['item_price [$]'] < upper_lim) & (chipotle['item_price [$]'] > lower_lim)]
# Out:
#       order_id  quantity                              item_name  \
# 1            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                                   Izze
# 3            1         1                       Nantucket Nectar
# 4            1         1  Chips and Tomatillo-Green Chili Salsa
# 6            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4613      1831         1                          Carnitas Bowl
# 4614      1831         1                                  Chips
# 4615      1831         1                          Bottled Water
# 4617      1832         1                    Chips and Guacamole
# 4620      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price [$]
# 1                                                   NaN            2.39
# ...

# %% [markdown]
# Limiting outliers instead of deleting - esp. important for small datasets (for large datasets, removing redundant information is not a problem).

# %%
upper_lim = chipotle['item_price [$]'].quantile(.95)
lower_lim = chipotle['item_price [$]'].quantile(.05)

chipotle.loc[(chipotle['item_price [$]'] > upper_lim), 'item_price [$]'] = upper_lim
chipotle.loc[(chipotle['item_price [$]'] < lower_lim), 'item_price [$]'] = lower_lim

# %% [markdown]
# ### Standardization
#
# Standardization consists in standardizing the various data formats in a set:
# * language coding style: UTF-8, ANSI etc.,
# * Dates: Sep 12, 2019, Sep 12, 2019, 120919 etc.,
# * New York City, NY, Z. New York,
# * MIT, Massachusetts Institute of Technology
# * Unrecognizable signs.

# %% [markdown]
# ### Discretization
#
# Continuous data distribution is bad for most machine learning algorithms.
#
# <img src="https://drive.google.com/uc?export=view&id=1O8fuKpYz3hR2Ab6d7SOUZLrvQWqDzM55" alt="Data processing: discretization" title="Data processing: discretization" align="right" width="300px" hspace="20px" vspace="20px"/>
#
# > numerical binning example
#
# | Value  | Bin  |
# | ------ | ---- |
# | 0-30   | Low  |
# | 31-70  | Mid  |
# | 71-100 | High |
#
# > categorical binning example
#
# | Value  | Bin  |
# | ------ | ---- |
# | Spain  | Europe |
# | Italy  | Europe |
# | Chile  | South America |
# | Brazil | South America |

# %% [markdown]
# ### Logarithmic transformation
#
# * helps to deal with skewed data
# * organizes the size of the data
# * reduces the impact of outliers
# * increases the reliability of the model
# * negative values need to be dealt with

# %%
(chipotle['item_price [$]'] + 1).transform(np.log)
# Out:
# 1       1.220830
# 2       1.479329
# 3       1.479329
# 4       1.220830
# 5       2.545531
#           ...
# 4618    2.545531
# 4619    2.545531
# 4620    2.505526
# 4621         NaN
# 4622         NaN
# Name: item_price [$], Length: 4622, dtype: float64

# %%
# if there are negative values present
(chipotle['item_price [$]'] - chipotle['item_price [$]'].min() + 1).transform(np.log)
# Out:
# 1       0.760806
# 2       1.144223
# 3       1.144223
# 4       0.760806
# 5       2.442347
#           ...
# 4618    2.442347
# 4619    2.442347
# 4620    2.397895
# 4621         NaN
# 4622         NaN
# Name: item_price [$], Length: 4622, dtype: float64

# %% [markdown]
# ### One-hot encoding (dummy variables)
#
# | User   | City     | → | User | Istanbul | Madrid |
# | ------ | ----     | --- | --- | --- | --- |
# | 1      | Roma     | → | 1 | 0 | 0 |
# | 2      | Madrid   | → | 2 | 0 | 1 |
# | 1      | Madrid   | → | 1 | 0 | 1 |
# | 3      | Istanbul | → | 3 | 1 | 0 |
# | 2      | Istanbul | → | 2 | 1 | 0 |
# | 1      | Istanbul | → | 1 | 1 | 0 |
# | 1      | Roma     | → | 1 | 0 | 0 |

# %% [markdown]
# ### GroupBy & apply
#
# <img src="https://drive.google.com/uc?export=view&id=17TC0l9R_fE2-d932J6YILBCUu8pj_ox7" alt="Data processing: groupby" title="Data processing: groupby" align="left" width="600px" hspace="20px" vspace="20px"/>

# %%
chipotle
# Out:
#       order_id  quantity                              item_name  \
# 1            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                                   Izze
# 3            1         1                       Nantucket Nectar
# 4            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4618      1833         1                          Steak Burrito
# 4619      1833         1                          Steak Burrito
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
# 4622      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price [$]
# 1                                                   NaN            2.39
# ...

# %%
chipotle.groupby('item_name').sum()[['quantity', 'item_price [$]']]
# Out:
#                                        quantity  item_price [$]
# item_name
# 6 Pack Soft Drink                            55          355.72
# Barbacoa Bowl                                66          672.36
# Barbacoa Burrito                             91          894.75
# Barbacoa Crispy Tacos                        12          113.46
# Barbacoa Salad Bowl                          10          105.70
# Barbacoa Soft Tacos                          25          250.46
# Bottled Water                               211          302.83
# Bowl                                          4           19.15
# Burrito                                       6           44.40
# Canned Soda                                 126          150.78
# Canned Soft Drink                           351          438.75
# Carnitas Bowl                                71          701.46
# Carnitas Burrito                             60          591.08
# ...

# %% [markdown]
# ### Split text
#
# Useful when you have multiple traits in one column.

# %%
chipotle['item_name'].str.split(' ').map(lambda x: x[0])
# Out:
# 1           Chips
# 2            Izze
# 3       Nantucket
# 4           Chips
# 5         Chicken
#           ...
# 4618        Steak
# 4619        Steak
# 4620      Chicken
# 4621      Chicken
# 4622      Chicken
# Name: item_name, Length: 4622, dtype: object

# %%
chipotle[chipotle['item_name'].str.startswith('Chicken')]['item_name'].value_counts()
# Out:
# Chicken Bowl            726
# Chicken Burrito         553
# Chicken Soft Tacos      115
# Chicken Salad Bowl      110
# Chicken Crispy Tacos     47
# Chicken Salad             9
# Name: item_name, dtype: int64

# %% [markdown]
# ### Scaling
#
# In most cases, the numerical characteristics of a dataset are not specific and vary from one another. In fact, it doesn't make sense to expect the age and income columns to have the same range. But from a machine learning perspective, the same scope helps improve the model.
#
# Scaling solves this problem. Continuous functions become range identical after the scaling process. This process is not mandatory for many algorithms, but still worthwhile. However, distance-based algorithms such as k-NN or k-Means must have scaled continuous functions as model inputs.
# Basically, there are two common ways to scale: normalization and standardization.

# %%
chipotle['item_price [$]'].describe()
# Out:
# count    3892.000000
# mean        6.947333
# std         3.915795
# min         1.250000
# 25%         2.950000
# 50%         8.490000
# 75%        11.250000
# max        11.750000
# Name: item_price [$], dtype: float64

# %%
# normalization

item_price_normalized = (chipotle['item_price [$]'] - chipotle['item_price [$]'].min()) / \
(chipotle['item_price [$]'].max() - chipotle['item_price [$]'].min())

# %%
item_price_normalized.describe()
# Out:
# count    3892.000000
# mean        0.142104
# std         0.106273
# min         0.000000
# 25%         0.043095
# 50%         0.171455
# 75%         0.235403
# max         1.000000
# Name: item_price [$], dtype: float64

# %%
# standardization

item_price_standardized = (chipotle['item_price [$]'] - chipotle['item_price [$]'].mean()) / \
chipotle['item_price [$]'].std()

# %%
item_price_standardized.describe()
# Out:
# count    3.892000e+03
# mean    -4.518482e-17
# std      1.000000e+00
# min     -1.454962e+00
# 25%     -1.020823e+00
# 50%      3.939601e-01
# 75%      1.098798e+00
# max      1.226486e+00
# Name: item_price [$], dtype: float64

# %% [markdown]
# ### Data extraction

# %%
from datetime import date

# %%
data = pd.DataFrame({
    'date': ['01-01-2017', '04-12-2008', '23-06-1988', '25-08-1999', '20-02-1993']
})

data
# Out:
#          date
# 0  01-01-2017
# 1  04-12-2008
# 2  23-06-1988
# 3  25-08-1999
# 4  20-02-1993

# %%
data['date'] = pd.to_datetime(data.date, format="%d-%m-%Y")

# %%
data['date'].dt.year
# Out:
# 0    2017
# 1    2008
# 2    1988
# 3    1999
# 4    1993
# Name: date, dtype: int64

# %%
data['date'].dt.month
# Out:
# 0     1
# 1    12
# 2     6
# 3     8
# 4     2
# Name: date, dtype: int64

# %%
data['date'].dt.day
# Out:
# 0     1
# 1     4
# 2    23
# 3    25
# 4    20
# Name: date, dtype: int64

# %%
data['date'].dt.day_of_week
# Out:
# 0    6
# 1    3
# 2    3
# 3    2
# 4    5
# Name: date, dtype: int64

# %%
data['passed_years'] = date.today().year - data['date'].dt.year

# %%
data['passed_months'] = 12 * data['passed_years'] + date.today().month - data['date'].dt.month

# %%
data['day_name'] = data['date'].dt.day_name()

# %%
data
# Out:
#         date  passed_years  passed_months   day_name
# 0 2017-01-01             6             81     Sunday
# 1 2008-12-04            15            178   Thursday
# 2 1988-06-23            35            424   Thursday
# 3 1999-08-25            24            290  Wednesday
# 4 1993-02-20            30            368   Saturday

# %% [markdown]
# ### Feature engineering example
#
# How to assess whether a given profile on Facebook is not a bot?
# * number of friends
# * number of posts published
# * number of photos
# * number of likes
# * likes under posts
# * the length of the posts
# * the origin of the phone number
# * e-mail address domain
#
# And the rating of the attractiveness of a movie on YouTube?

# %% [markdown]
# The car rental company ARRA wants to evaluate the reliability and maintenance costs of the different car models available in the fleet. It has the following data:
# * a table with individual activities of all cars in the fleet: date, place of rental, status (driving, breakdown), renting data (age, sex, nationality), number of kilometers traveled, amount of fuel consumed, car identification number
# * a table for each car: year of production, engine, equipment, brand, model, etc.
#
#
# What features can we find here?

# %% [markdown]
# > Fun fact<br>
# The process of obtaining, preprocessing data and extracting features from them takes up to 80% of a data engineer's work time.
#
# ## Further readings
#
# 1. [30 Examples to Get You From a Novice to an Advanced Pandas User](https://towardsdatascience.com/30-examples-to-get-you-from-a-novice-to-an-advanced-pandas-user-e6eb4e8750b7)
#     * `.insert()` - to create a new column at a specific position
#     * `.unique()` and `.nunique()` - to get all unique values and their number, respectively
#     * `.isin()` - to check which rows are contained in a given collection of items
#     * `.rank()` - to assign order IDs without sorting the set
#     * `.plot()`, `.hist()` - to make basic data vizualizations
# 1. using `.groupby()` with external values (not a DataFrame column)
# 1. use `.pipe()` if you want to write a concise code with all data processing steps included in a single pipeline
# 1. `.explode()` - to change the data format from wide to long
# 1. `.between()` - to simultaneously check if the data is limited on both sides
# 1. `.T` - to swap rows and columns with each other (just like transposing a matrix - more soon)
# 1. `.nlargest()` & `.nsmallest()` - to find the $n$ top/bottom values
# 1. `.clip()` - to limit the values by a given value, ie. if the value exceeds than set it to the upper/lower limit
# 1. `.stack()`, `.unstack()`, `.pivot()` - read more https://pandas.pydata.org/docs/user_guide/reshaping.html

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1UO2urRciECzoKE_vHy4RMGfFbkOWOGlW" alt="SDA logo" align="left" width="100px" hspace="10px" vspace="10px"/>
# <br>
#
# # TASKS

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>1</font>**
#
# Create a dataframe with the 10 names of pupils and the number of points they obtained in the exam. Then check what the mean and median of the results were.

# %%
import pandas as pd

# df = pd.DataFrame({'name':['Alena','Mila','Jan','Ondra','Jana','Libor','Alex','Viktor','Pepa','Max'],'points':[95,22,15,67,50,20,80,64,10,90]})

df = pd.DataFrame(
    [
        ['Alena', 25],
        ['Mila', 65],
        ['Jan', 29],
        ['Ondra', 65],
        ['Jana', 86],
        ['Libor', 75],
        ['Alex', 42],
        ['Viktor', 74],
        ['Pepa', 49],
        ['Max', 37]
    ]
)

df.columns = ('name', 'points')

df
# Out:
#      name  points
# 0   Alena      25
# 1    Mila      65
# 2     Jan      29
# 3   Ondra      65
# 4    Jana      86
# 5   Libor      75
# 6    Alex      42
# 7  Viktor      74
# 8    Pepa      49
# 9     Max      37

# %%
#mean_points = df['points'].mean()
print(f'mean is: {df.points.mean()}')
print(f'median is: {df.points.median()}')
# Out:
# mean is: 54.7
# median is: 57.0

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2</font>**
#
# Based on the data frame created in the previous task, display the fourth line. Then write those students who scored above average to a separate box.

# %%
print(f"{df.iloc[3]}\n")

print(df[df.points>df.points.mean()])
# Out:
# name      Ondra
# points       65
# Name: 3, dtype: object
#
#      name  points
# 1    Mila      65
# 3   Ondra      65
# 4    Jana      86
# 5   Libor      75
# 7  Viktor      74

# %%
from google.colab import drive
# drive.mount('/content/drive')

# %%
# !ls "/content/sample_data/"
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# bonus - write in file

with open('/content/sample_data/pupils_above_average.txt', 'w') as f:
    f.write(str(df[df.points>df.points.mean()]))
    f.write('Created in Python\n')

# %%
# !ls "/content/sample_data/"
# Out:
# anscombe.json		      mnist_test.csv		README.md
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  pupils_above_average.txt

# %%
with open('/content/sample_data/pupils_above_average.txt') as f:
    for line in f:
        print(line)
# Out:
#      name  points
#
# 1    Mila      65
#
# 3   Ondra      65
#
# 4    Jana      86
#
# 5   Libor      75
#
# 7  Viktor      74Created in Python

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>3</font>**
#
# Add a third column to the box which will contain the percentage of student scores on this exam (that is, each numerical value must be divided by the maximum score that could be obtained on this exam).
#
# Next, we want to anonymize the first name column: we want only the first and last letters of the first name to be left. For example, for the name "John" we want to keep "J ... n".

# %%
#max_points = df.points.max()
df['percent'] = df.points.apply(lambda x: 100*x/90) # max points is 90
df['percent1'] = 100*df.points/90 # max points is 90 - ver 2 apply is faster
df['percentile'] = df.points.apply(lambda x: 100*x/df.points.max())
df['name_anonym'] = df.name.apply(lambda x: x[0]+'...' + x[-1])
print(df)
# Out:
#      name  points    percent   percent1  percentile name_anonym
# 0   Alena      25  27.777778  27.777778   29.069767       A...a
# 1    Mila      65  72.222222  72.222222   75.581395       M...a
# 2     Jan      29  32.222222  32.222222   33.720930       J...n
# 3   Ondra      65  72.222222  72.222222   75.581395       O...a
# 4    Jana      86  95.555556  95.555556  100.000000       J...a
# 5   Libor      75  83.333333  83.333333   87.209302       L...r
# 6    Alex      42  46.666667  46.666667   48.837209       A...x
# 7  Viktor      74  82.222222  82.222222   86.046512       V...r
# 8    Pepa      49  54.444444  54.444444   56.976744       P...a
# 9     Max      37  41.111111  41.111111   43.023256       M...x

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>4</font>**
#
# Sort the data frame by the number of points obtained for the exam, from highest to lowest. In case of the same number of points, the persons should be displayed in alphabetical order.

# %%
# df.sort_values(['points','name'],ascending=[False,True]) variant 1

df.sort_values('name').sort_values('points',ascending=False) # variant 2
# Out:
#      name  points    percent   percent1  percentile name_anonym
# 4    Jana      86  95.555556  95.555556  100.000000       J...a
# 5   Libor      75  83.333333  83.333333   87.209302       L...r
# 7  Viktor      74  82.222222  82.222222   86.046512       V...r
# 1    Mila      65  72.222222  72.222222   75.581395       M...a
# 3   Ondra      65  72.222222  72.222222   75.581395       O...a
# 8    Pepa      49  54.444444  54.444444   56.976744       P...a
# 6    Alex      42  46.666667  46.666667   48.837209       A...x
# 9     Max      37  41.111111  41.111111   43.023256       M...x
# 2     Jan      29  32.222222  32.222222   33.720930       J...n
# 0   Alena      25  27.777778  27.777778   29.069767       A...a

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>5</font>**
#
# Join the two dataframes defined below:
# ```python
# student_data1 = pd.DataFrame({
#     'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
#     'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin']
# })
# ```
# together with:
# ```python
# student_data2 = pd.DataFrame({
#     'student_id': ['S6', 'S7', 'S8', 'S9', 'S10'],
#     'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston']
# })
# ```

# %%
import pandas as pd

student_data1 = pd.DataFrame({
    'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
    'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin']
})

student_data2 = pd.DataFrame({
    'student_id': ['S6', 'S7', 'S8', 'S9', 'S10'],
    'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston']
})

print(pd.concat([student_data1, student_data2]).reset_index().sort_values('name')) # , axis=1

students_data = pd.concat([student_data1, student_data2]).reset_index()
# Out:
#    index student_id              name
# 2      2         S3      Bryce Jensen
# 6      1         S7  Carla Williamson
# 0      0         S1  Danniella Fenton
# 7      2         S8       Dante Morse
# 3      3         S4         Ed Bernal
# 8      3         S9    Kaiser William
# 4      4         S5       Kwame Morin
# 9      4        S10   Madeeha Preston
# 1      1         S2      Ryder Storey
# 5      0         S6  Scarlette Fisher

# %%
print(student_data1.append(student_data2))
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Out:
#   student_id              name
# 0         S1  Danniella Fenton
# 1         S2      Ryder Storey
# 2         S3      Bryce Jensen
# 3         S4         Ed Bernal
# 4         S5       Kwame Morin
# 0         S6  Scarlette Fisher
# 1         S7  Carla Williamson
# 2         S8       Dante Morse
# 3         S9    Kaiser William
# 4        S10   Madeeha Preston
# <ipython-input-43-b6f3883c46d6>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   print(student_data1.append(student_data2))

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>6</font>**
#
# To the box created in the previous task, add the information about the students' results from the box below.
# ```python
# exam_results = pd.DataFrame({
#     'student_id': ['S2', 'S10', 'S3', 'S1', 'S7', 'S9', 'S5', 'S4', 'S8', 'S6'],
#     'marks': [200, 210, 190, 222, 199, 201, 200, 198, 219, 201]
# })
# ```

# %%
exam_results = pd.DataFrame({
    'student_id': ['S2', 'S10', 'S3', 'S1', 'S7', 'S9', 'S5', 'S4', 'S8', 'S6'],
    'marks': [200, 210, 190, 222, 199, 201, 200, 198, 219, 201]
})

# %%
students_data_exam = pd.merge(students_data,exam_results,on='student_id')

print(students_data_exam)
# Out:
#    index student_id              name  marks
# 0      0         S1  Danniella Fenton    222
# 1      1         S2      Ryder Storey    200
# 2      2         S3      Bryce Jensen    190
# 3      3         S4         Ed Bernal    198
# 4      4         S5       Kwame Morin    200
# 5      0         S6  Scarlette Fisher    201
# 6      1         S7  Carla Williamson    199
# 7      2         S8       Dante Morse    219
# 8      3         S9    Kaiser William    201
# 9      4        S10   Madeeha Preston    210

# %% [markdown]
# Additional tasks...

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>7</font>**
#
# Create two objects of type `pd.Series()`, containing 100 values of 0 or 1. Use a random number generator from the NumPy library, eg. `np.random.randint()`. Then display all the indexes on which the values in both `pd.Series()` match.

# %%
# my solution
import pandas as pd
import numpy as np

obj1 = pd.Series(np.random.randint(2, size=100))

obj2 = pd.Series(np.random.randint(2, size=100))

result = []

for i in obj1.index:
    if obj1[i] == obj2[i]:
        result += [i]

print(result)
print(len(result))
# Out:
# [1, 3, 4, 9, 10, 11, 12, 13, 16, 19, 20, 22, 23, 24, 25, 26, 27, 28, 29, 30, 34, 39, 42, 44, 47, 49, 53, 54, 55, 57, 59, 60, 62, 64, 67, 70, 72, 73, 74, 75, 77, 78, 79, 82, 86, 88, 89, 91, 95, 98, 99]
# 51

# %%
# openai solution
import numpy as np
import pandas as pd

# Generate two random Series with 100 values of 0 or 1
series1 = pd.Series(np.random.randint(2, size=100))
series2 = pd.Series(np.random.randint(2, size=100))

# Create a boolean mask to check for equality
match_mask = series1 == series2

# Get the indexes where values match
matching_indexes = match_mask.index[match_mask]

# Display the matching indexes
print("Indexes where values match:")
print(matching_indexes)

print(len(matching_indexes))
# Out:
# Indexes where values match:
# Int64Index([ 0,  2,  3,  4,  7,  9, 10, 13, 14, 18, 19, 20, 26, 29, 30, 31, 32,
#             37, 39, 40, 41, 42, 43, 44, 45, 46, 50, 52, 53, 55, 56, 57, 60, 63,
#             64, 67, 68, 73, 74, 76, 77, 81, 83, 86, 90, 91, 96, 98, 99],
#            dtype='int64')
# 49

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>8</font>**
#
# Create a `pd.DataFrame()` with ten male and female students' names as well as the number of points they scored on the exam. Then check what the mean and median scores were.
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html
#
# ```python
# df = pd.DataFrame(data)
# ```

# %%
import pandas as pd

# df = pd.DataFrame({'name':['Alena','Mila','Jan','Ondra','Jana','Libor','Alex','Viktor','Pepa','Max'],'points':[95,22,15,67,50,20,80,64,10,90]})
df = pd.DataFrame(
    [
        ['Alena', 25],
        ['Mila', 65],
        ['Jan', 29],
        ['Ondra', 65],
        ['Jana', 86],
        ['Libor', 75],
        ['Alex', 42],
        ['Viktor', 74],
        ['Pepa', 49],
        ['Max', 37]
    ]
)

df.columns = ('name', 'points')

df

print(f"Mean: {df.points.mean()}")
print(f"Median: {df.points.median()}")
# Out:
# Mean: 54.7
# Median: 57.0

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>9</font>**
#
# * Based on the data frame created in the previous task, display the fourth row.
# * Then write into a separate frame those students who scored above the average.

# %%
print(df.iloc[3])

df_above = df[df.points>df.points.mean()]
print(df_above)
# Out:
# name      Ondra
# points       65
# Name: 3, dtype: object
#      name  points
# 1    Mila      65
# 3   Ondra      65
# 4    Jana      86
# 5   Libor      75
# 7  Viktor      74

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>10</font>**
#
# Add to the data frame a third column, which will contain the percentage score of each student on that exam (that is, each numerical value must be divided by the maximum score that could be obtained on that exam).
#
# Next, we want to anonymize the name column: we want only the first and last letters of the name to remain. For example, we want to keep `J...n` for the name `John`.

# %%
df["percentage"] = df.points.apply(lambda x: 100*x/90)
df["anonym"] = df.name.apply(lambda x: x[0] + "..." + x[-1])

print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["percentage"] = df.points.apply(lambda x: 100*x/90)
#       2 df["anonym"] = df.name.apply(lambda x: x[0] + "..." + x[-1])
#       4 print(df)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>11</font>**
#
# Search https://academic.udayton.edu/kissock/http/weather/citylistWorld.htm for weather data for the capital city of Bangladesh (Dhaka). Save the data frame as the variable `df_dhaka`. Copy the link to a text file and load the data using `pd.read_csv()`.
#
# Hint: using the arguments - header, sep, and names is a good idea.
#
# Meta-data: https://academic.udayton.edu/kissock/http/weather/source.htm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
#  Volume in drive E is DATA
#  Volume Serial Number is 491A-F0B7
#
#  Directory of E:\@DataScienceCZ7\6_Python_in_Data_Science
#
# 23.10.2023  22:11    <DIR>          .
# 23.10.2023  20:28    <DIR>          ..
# 14.10.2023  19:44                36 .gitignore
# 23.10.2023  19:56    <DIR>          .idea
# 23.10.2023  19:59    <DIR>          .ipynb_checkpoints
# 23.10.2023  22:11           614 323 6_Python_in_Data_Science.ipynb
# 23.10.2023  20:50    <DIR>          data
# 13.10.2023  14:01               590 main.py
# 13.10.2023  14:01               278 pandas_test.py
# 07.10.2023  11:36    <DIR>          scripts
# 23.10.2023  20:00               461 task_1_and_2.py
# 15.10.2023  17:58                72 testa.py
# 23.10.2023  19:54                72 Untitled.ipynb
# 23.10.2023  19:59                72 Untitled1.ipynb
# 08.10.2023  09:29    <DIR>          venv
#                8 File(s)        615 904 bytes
#                7 Dir(s)  192 551 960 576 bytes free

# %%
import pandas as pd

# f = open('/content/drive/MyDrive/Colab Notebooks/6 Python in Data Science/weather_history_bangladesh.csv')
df_dhaka = pd.read_csv('./data/dhaka_temperature.csv')

# pd.read_csv()
df_dhaka
# Out:
#       Unnamed: 0 Region     Country  State   City  Month  Day  Year  \
# 0         251118   Asia  Bangladesh    NaN  Dhaka      1    1  1995
# 1         251119   Asia  Bangladesh    NaN  Dhaka      1    2  1995
# 2         251120   Asia  Bangladesh    NaN  Dhaka      1    3  1995
# 3         251121   Asia  Bangladesh    NaN  Dhaka      1    4  1995
# 4         251122   Asia  Bangladesh    NaN  Dhaka      1    5  1995
# ...          ...    ...         ...    ...    ...    ...  ...   ...
# 5805      256923   Asia  Bangladesh    NaN  Dhaka     11   22  2010
# 5806      256924   Asia  Bangladesh    NaN  Dhaka     11   23  2010
# 5807      256925   Asia  Bangladesh    NaN  Dhaka     11   24  2010
# 5808      256926   Asia  Bangladesh    NaN  Dhaka     11   25  2010
# 5809      256927   Asia  Bangladesh    NaN  Dhaka     11   26  2010
#
#       AvgTemperature
# 0               64.8
# 1               58.4
# 2              -99.0
# 3               59.6
# 4               64.9
# ...

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>12</font>**
#
# In the `df_dhaka` dataset, change the index values for the rows so that they start at 1.
#
# Then display:
# * first 10 rows
# * third row both using .loc[] and 'iloc[] - compare the outputs

# %%
df_dhaka.index = range(1, len(df_dhaka) + 1)

# %%
df_dhaka.loc[1:10]
# Out:
#       date     time  temperature_fahrenheit  dew_point_fahrenheit  \
# 1   1/1/23  0:00:00                      66                    59
# 2   1/1/23  0:30:00                      66                    59
# 3   1/1/23  1:00:00                      66                    61
# 4   1/1/23  1:30:00                      64                    61
# 5   1/1/23  2:00:00                      64                    61
# 6   1/1/23  2:30:00                      64                    61
# 7   1/1/23  3:00:00                      63                    59
# 8   1/1/23  3:30:00                      63                    59
# 9   1/1/23  4:00:00                      63                    61
# 10  1/1/23  4:30:00                      61                    59
#
#    humidity_percentage  wind  wind_speed_mph  wind_gust_mph  pressure_in  \
# 1                   78  CALM               0              0        30.06
# 2                   78  CALM               0              0        30.03
# ...

# %%
df_dhaka.iloc[0:10]
# Out:
#       date     time  temperature_fahrenheit  dew_point_fahrenheit  \
# 1   1/1/23  0:00:00                      66                    59
# 2   1/1/23  0:30:00                      66                    59
# 3   1/1/23  1:00:00                      66                    61
# 4   1/1/23  1:30:00                      64                    61
# 5   1/1/23  2:00:00                      64                    61
# 6   1/1/23  2:30:00                      64                    61
# 7   1/1/23  3:00:00                      63                    59
# 8   1/1/23  3:30:00                      63                    59
# 9   1/1/23  4:00:00                      63                    61
# 10  1/1/23  4:30:00                      61                    59
#
#    humidity_percentage  wind  wind_speed_mph  wind_gust_mph  pressure_in  \
# 1                   78  CALM               0              0        30.06
# 2                   78  CALM               0              0        30.03
# ...

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>13</font>**
#
# View all observations:
# * from May 2000
# * from January 1 of each year

# %%
df_dhaka.sort_values(by='temperature_fahrenheit',ascending=True)  # ["date","time"]
# Out:
#            date      time  temperature_fahrenheit  dew_point_fahrenheit  \
# 733   1/16/2023   9:00:00                      50                    59
# 345      1/8/23   6:30:00                      54                    54
# 344      1/8/23   6:00:00                      54                    54
# 343      1/8/23   5:30:00                      54                    52
# 342      1/8/23   5:00:00                      54                    52
# ...         ...       ...                     ...                   ...
# 2083  6/13/2022  15:00:00                      93                    75
# 2034    6/12/22  14:30:00                      93                    77
# 2611  6/24/2022  15:00:00                      95                    79
# 2610  6/24/2022  14:30:00                      95                    77
# 2609  6/24/2022  14:00:00                      95                    77
#
#      humidity_percentage  wind  wind_speed_mph  wind_gust_mph  pressure_in  \
# ...

# %%
df_group = df_dhaka.groupby(['date']).agg(
    temperature_min=('temperature_fahrenheit', 'min'),
    temperature_max=('temperature_fahrenheit', 'max'),
    temperature_mean=('temperature_fahrenheit', 'mean'),
    datetime1=('datetime', 'max')
    )

df_group.temperature_mean = df_group.temperature_mean.round(1)

df_group.sort_values(by='datetime1')
# Out:
#            temperature_min  temperature_max  temperature_mean  \
# date
# 6/1/22                  82               91              84.5
# 6/2/22                  81               91              84.8
# 6/3/22                  79               90              83.8
# 6/4/22                  82               90              83.3
# 6/5/22                  81               93              86.8
# ...                    ...              ...               ...
# 1/28/2023               64               82              73.2
# 1/29/2023               64               79              70.3
# 1/30/2023               64               84              72.1
# 1/31/2023               64               84              73.6
# 6/6/23                  84               93              88.3
#
#                     datetime1
# date
# 6/1/22    2022-06-01 23:30:00
# 6/2/22    2022-06-02 23:30:00
# 6/3/22    2022-06-03 23:30:00
# 6/4/22    2022-06-04 23:30:00
# 6/5/22    2022-06-05 23:30:00
# ...

# %%
from datetime import date

df_dhaka["datetime"] = pd.to_datetime(df_dhaka["date"] + " " + df_dhaka["time"])

# filt1 =

df_dhaka[(df_dhaka.datetime>='2000-5-1') & (df_dhaka.datetime.dt.day == 1) & (df_dhaka.datetime.dt.hour == 0) & (df_dhaka.datetime.dt.minute == 0)] # & (df_dhaka.datetime.dt.month == 1)
# Out:
#         date     time  temperature_fahrenheit  dew_point_fahrenheit  \
# 0     1/1/23  0:00:00                      66                    59
# 1481  6/1/22  0:00:00                      82                    73
#
#      humidity_percentage  wind  wind_speed_mph  wind_gust_mph  pressure_in  \
# 0                     78  CALM               0              0        30.06
# 1481                  74    SE               3              0        29.56
#
#       precip._in condition   datetime
# 0              0       Fog 2023-01-01
# 1481           0      Haze 2022-06-01

# %%
df_dhaka['datetime'] = pd.to_datetime(df_dhaka['datetime'])

# Filter the DataFrame based on the specified conditions
filtered_df = df_dhaka[(df_dhaka['datetime'].dt.year >= 2000) &
                       ((df_dhaka['datetime'].dt.month == 5) |
                        ((df_dhaka['datetime'].dt.month == 1) & (df_dhaka['datetime'].dt.day == 1)))]

# Display the filtered DataFrame
print(filtered_df)
# Out:
#       date      time  temperature_fahrenheit  dew_point_fahrenheit  \
# 1   1/1/23   0:00:00                      66                    59
# 2   1/1/23   0:30:00                      66                    59
# 3   1/1/23   1:00:00                      66                    61
# 4   1/1/23   1:30:00                      64                    61
# 5   1/1/23   2:00:00                      64                    61
# 6   1/1/23   2:30:00                      64                    61
# 7   1/1/23   3:00:00                      63                    59
# 8   1/1/23   3:30:00                      63                    59
# 9   1/1/23   4:00:00                      63                    61
# 10  1/1/23   4:30:00                      61                    59
# 11  1/1/23   5:00:00                      61                    59
# 12  1/1/23   5:30:00                      61                    59
# 13  1/1/23   6:00:00                      61                    59
# ...

# %%
import pandas as pd

# Corrected format string for "month/day/year" format
date_string = '1/1/23'
parsed_date = pd.to_datetime(date_string, format="%m/%d/%y")

print(parsed_date)
# Out:
# 2023-01-01 00:00:00

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>14</font>**
#
# Delete all rows containing missing data, i.e. `-99.0`. Reset the indexes of the rows (see the `.reset_index()` method).

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>15</font>**
#
# Enter a new column `average daily temperature (C)` containing the average temperature in degrees Celsius.
# * Round the result to one decimal place.
# * Determine the average temperature recorded in Dhaka over the years, and determine the lowest and highest value.

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>16</font>**
#
# Sort the data frame from **Task 8** by the number of points received from the exam, from highest to lowest. In the case of the same number of points, individuals are to be displayed in alphabetical order.

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>17</font>**
#
# Join the following two frames together:
#
# ```python
# student_data1 = pd.DataFrame({
#     'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
#     'name': ['Daniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin']]
# })
#
# student_data2 = pd.DataFrame({
#     'student_id': ['S6', 'S7', 'S8', 'S9', 'S10'],
#     'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston']]
# })
# ```

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>18</font>**
#
# Add information about the results of the students in the box below to the box created in the previous task:
#
# ```python
# exam_results = pd.DataFrame({
#     'student_id': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10'],
#     'marks': [200, 210, 190, 222, 199, 201, 200, 198, 219, 201]
# })
# ```

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>19</font>**
#
# Download temperature data for an additional selected city https://academic.udayton.edu/kissock/http/weather/citylistWorld.htm. Combine the data with `df_dhaka` in such a way that the values in the day, month and year columns are not duplicated (i.e. for each date two columns with temperature for the corresponding cities).
#
# Hint(s):
# * see https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# * tip sep=' +' or sep='\s+' (regular expression for one space or more)

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>20</font>**
#
# For the data frame from **Task 19**:
# * fill in the missing data with the
#     * mean value
#     * median
# * remove outlier observations
# * enter a new column with discrete values for temperature (you can use the `cut()` or `qcut()` methods from the `pandas` library)
# * enter the so-called *dummy variables* defining the city `Dhaka` vs `Your_city`.
# * determine the average annual temperature using the `.groupby()` method
# * use normalization or standardization to scale the temperature data
# * create an additional `date` column containing the date in `pd.DateTime()` format
#
# Tips:
# * the missing data in the form `-99` can be replaced with something standard, e.g. `df_dhaka = df_dhaka.replace(-99, np.NaN)` then all standard methods such as: `.isna(), .isnull(), .fillna(), .dropna()` can be used
# * to generate dummy variables, the so-called one-hot-encoding can be used:
#     * `pd.get_dummies()` from pandas
#     * `sklearn.preprocessing.OneHotEncoder` from scikit-learn
#     * `tf.keras.layers.CategoryEncoding` from tensorflow
# * data scaling can be done as in the slides or with the scikit-learn library, such as `sklearn.preprocessing.StandardScaler` or `sklearn.preprocessing.MinMaxScaler`
